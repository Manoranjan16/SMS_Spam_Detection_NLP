# %%
import pandas as pd

# %%
df = pd.read_csv('SMSSpamCollection', sep='\t', header=None, names=['label', 'message'])

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
# Only spam 5 dataset will check
df[df['label'] == 'spam'].head()
# Out:
#    label                                            message
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...
# 8   spam  WINNER!! As a valued network customer you have...
# 9   spam  Had your mobile 11 months or more? U R entitle...
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...

# %%
# Only ham 5 dataset will check
df[df['label'] == 'ham'].head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
# 6   ham  Even my brother is not like to speak with me. ...

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df['label'].value_counts().plot(kind='bar')
plt.xlabel("Message Type")
plt.ylabel('Number of Message')
plt.title("Spam vs Ham Messages")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df["message"].duplicated().sum()
# Out:
# np.int64(403)

# %%
df1 = df.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1['label'] = df['label'].map({
    "ham": 0,
    "spam": 1
})

df1.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
X = df1['message']
y = df1['label']

print(X.head())
print()
print(y.head())
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: message, dtype: object
#
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
df1['label'].value_counts()
# Out:
# label
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4135,), (1034,), (4135,), (1034,))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()

X_train_idf = tfidf.fit_transform(X_train)
X_test_idf = tfidf.transform(X_test)

X_train_idf.shape, X_test_idf.shape
# Out:
# ((4135, 7680), (1034, 7680))

# %%
tfidf.get_feature_names_out()[:20]
# Out:
# array(['00', '000', '000pes', '008704050406', '0089', '0121',
#        '01223585236', '01223585334', '0125698789', '02', '0207',
#        '02072069400', '03', '04', '0430', '05', '050703', '0578', '06',
#        '07'], dtype=object)

# %%
X_train_idf[0].shape
# Out:
# (1, 7680)

# %%
X_train.iloc[0], X_train_idf[0]
# Out:
# ('Ta-Daaaaa! I am home babe, are you still up ?',
#  <Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 9 stored elements and shape (1, 7680)>)

# %%
feature_name = tfidf.get_feature_names_out()

row = X_train_idf[0]

for index, value in zip(row.indices, row.data):
    print(feature_name[index], value)
# Out:
# am 0.27302453527471554
# are 0.22262669782699995
# babe 0.32889978169730083
# daaaaa 0.5494390936793128
# home 0.28681222213960167
# still 0.2883706884664802
# ta 0.46972053147573545
# up 0.24452632207532418
# you 0.14137598054893938

# %%
X_train.iloc[0]
# Out:
# 'Ta-Daaaaa! I am home babe, are you still up ?'
